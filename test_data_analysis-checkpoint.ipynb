# %%
# Import Dependencies
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read files into pandas DataFrames
pop_df = pd.read_csv("API_SP.POP.TOTL_DS2_en_csv_v2_713131.csv", header=2)
gdp_df = pd.read_csv("API_NY.GDP.MKTP.CD_DS2_en_csv_v2_713242.csv", header=2)
co2_df = pd.read_csv("API_EN.ATM.CO2E.PC_DS2_en_csv_v2_713061.csv", header=2)
gni_df = pd.read_csv("API_GNI_CLASS.csv", header=2)

# %%
# Set beginning and end time period
begin_year = "1995"
end_year = "2014"

# %%
# Population DataFrame
pop_a_df = pop_df.loc[:,["Country Name", "Country Code"]]
pop_b_df = pop_df.loc[:,"1995":"2014"]
pop_concat_df = pd.concat([pop_a_df,pop_b_df], axis=1)
pop_concat_df = pop_concat_df.set_index("Country Name")

# GDP DataFrame
gdp_a_df = gdp_df.loc[:,["Country Name", "Country Code"]]
gdp_b_df = gdp_df.loc[:,"1995":"2014"]
gdp_concat_df = pd.concat([gdp_a_df,gdp_b_df], axis=1)
gdp_concat_df = gdp_concat_df.set_index("Country Name")

# CO2 DataFrame
co2_a_df = co2_df.loc[:,["Country Name", "Country Code"]]
co2_b_df = co2_df.loc[:,"1995":"2014"] * 1000 # Convert metric tons to kg.
co2_concat_df = pd.concat([co2_a_df,co2_b_df], axis=1)
co2_concat_df = co2_concat_df.set_index("Country Name")

# GNI DataFrame
gni_a_df = gni_df.loc[:,["Country Name", "Country Code"]]
gni_b_df = gni_df.loc[:,"1995":"2014"]
gni_concat_df = pd.concat([gni_a_df,gni_b_df], axis=1)
gni_concat_df = gni_concat_df.set_index("Country Name")

# %%
pop_concat_df.head()
#gdp_concat_df.head()
#co2_concat_df.head()
#gni_concat_df.head()
# Out:
#              Country Code        1995        1996        1997        1998  \
# Country Name
# Aruba                 ABW     80324.0     83200.0     85451.0     87277.0
# Afghanistan           AFG  18110657.0  18853437.0  19357126.0  19737765.0
# Angola                AGO  13945206.0  14400719.0  14871570.0  15359601.0
# Albania               ALB   3187784.0   3168033.0   3148281.0   3128530.0
# Andorra               AND     63850.0     64360.0     64327.0     64142.0
#
#                     1999        2000        2001        2002        2003  ...  \
# Country Name                                                              ...
# Aruba            89005.0     90853.0     92898.0     94992.0     97017.0  ...
# Afghanistan   20170844.0  20779953.0  21606988.0  22600770.0  23680871.0  ...
# Angola        15866869.0  16395473.0  16945753.0  17519417.0  18121479.0  ...
# Albania        3108778.0   3089027.0   3060173.0   3051010.0   3039616.0  ...
# Andorra          64370.0     65390.0     67341.0     70049.0     73182.0  ...
#
#                     2005        2006        2007        2008        2009  \
# Country Name
# Aruba           100031.0    100834.0    101222.0    101358.0    101455.0
# Afghanistan   25654277.0  26433049.0  27100536.0  27722276.0  28394813.0
# Angola        19433602.0  20149901.0  20905363.0  21695634.0  22514281.0
# Albania        3011487.0   2992547.0   2970017.0   2947314.0   2927519.0
# Andorra          78867.0     80993.0     82684.0     83862.0     84463.0
#
#                     2010        2011        2012        2013        2014
# Country Name
# Aruba           101669.0    102046.0    102560.0    103159.0    103774.0
# Afghanistan   29185507.0  30117413.0  31161376.0  32269589.0  33370794.0
# Angola        23356246.0  24220661.0  25107931.0  26015780.0  26941779.0
# Albania        2913021.0   2905195.0   2900401.0   2895092.0   2889104.0
# Andorra          84449.0     83747.0     82427.0     80774.0     79213.0
#
# [5 rows x 21 columns]

# %%
# GDP per Capita DataFrame
gdppc_a_df = gdp_a_df
gdppc_b_df = gdp_concat_df.loc[:,"1995":"2014"].div(pop_concat_df.loc[:,"1995":"2014"])
gdppc_concat_df = pd.merge(gdppc_a_df, gdppc_b_df, on="Country Name")
gdppc_concat_df = gdppc_concat_df = gdppc_concat_df.set_index("Country Name")
gdppc_concat_df.head()
# Out:
#              Country Code          1995          1996          1997  \
# Country Name
# Aruba                 ABW  16439.356361  16586.068436  17927.749635
# Afghanistan           AFG           NaN           NaN           NaN
# Angola                AGO    397.179451    522.643807    514.295223
# Albania               ALB    750.604449   1009.977668    717.380567
# Andorra               AND  18461.064858  19017.174590  18353.059722
#
#                       1998          1999          2000          2001  \
# Country Name
# Aruba         19078.343191  19356.203389  20620.700626  20669.031969
# Afghanistan            NaN           NaN           NaN           NaN
# Angola          423.593660    387.784316    556.836318    527.333529
# Albania         813.790264   1033.241693   1126.683318   1281.659393
# Andorra       18894.521496  19261.710504  21936.530101  22228.846493
#
#                       2002          2003  ...          2005          2006  \
# Country Name                              ...
# Aruba         20436.887129  20833.761612  ...  23300.039558  24045.272483
# Afghanistan     179.426494    190.684009  ...    242.031379    263.733735
# Angola          872.494492    982.960899  ...   1902.422346   2599.566464
# Albania        1425.124849   1846.118813  ...   2673.787283   2972.743265
# Andorra       24741.493570  32776.442270  ...  41282.020122  43747.691849
#
#                       2007          2008          2009          2010  \
# Country Name
# Aruba         25835.132668  27084.703690  24630.453714  23512.602596
# Afghanistan     359.693480    364.660465    438.076034    543.303042
# Angola         3121.995637   4080.941410   3122.780766   3587.883798
# Albania        3595.037163   4370.540087   4114.140150   4094.362119
# Andorra       48582.220883  47785.089273  43338.866758  39736.354063
#
#                       2011          2012          2013          2014
# Country Name
# Aruba         24985.993281  24713.698045  25025.099563  25533.569780
# Afghanistan     591.162346    641.872034    637.165044    613.856333
# Angola         4615.468028   5100.095808   5254.882338   5408.410496
# Albania        4437.178067   4247.614279   4413.081743   4578.666720
# Andorra       41100.729938  38392.943901  40626.751632  42300.334128
#
# [5 rows x 21 columns]

# %%
# Ask user for country
country_input = input("Which country do you want to chart? ")
# Out:
# Which country do you want to chart? KOR

# %%
# Graph Population
# pop_search = pop_concat_df.loc[(pop_concat_df["Country Code"]==country_input),"1995":"2014"].T
# plt.plot(pop_search, marker='.', color='purple')

# Graph GDP
gdppc_search = gdppc_concat_df.loc[(gdppc_concat_df["Country Code"]==country_input),"1995":"2014"].T
plt.plot(gdppc_search, marker='o', color='green')

# Graph CO2
co2_search = co2_concat_df.loc[(co2_concat_df["Country Code"]==country_input),"1995":"2014"].T
plt.plot(co2_search, marker='o', color='orange')

plt.xticks(rotation=90)
plt.xlabel("GDP per capita (current US$)")
plt.ylabel("Population")
plt.title(country_input)
# plt.legend((gdppc_search, co2-search)('GDP per capita (current US$)', 'CO2 per capita (kg)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'KOR')

# %%
# Divide GDP by billions, population by millions
# gdppc_concat_df.loc[:, begin_year:end_year]=gdppc_concat_df.loc[:, begin_year:end_year]
# gdp_concat_df.loc[:, begin_year:end_year]=gdp_concat_df.loc[:, begin_year:end_year]
# pop_concat_df.loc[:, begin_year:end_year]=pop_concat_df.loc[:, begin_year:end_year]/1000000
# co2_concat_df.loc[:, begin_year:end_year]=co2_concat_df.loc[:, begin_year:end_year]*1000

# %%
# single_country='KOR'
# # one_country_gdp=gdppc_concat_df[gdppc_concat_df['Country Code']==single_country].loc[:, begin_year:end_year].T
# one_country_co2=co2_concat_df[co2_concat_df['Country Code']==single_country].loc[:, begin_year:end_year].T
# one_country_pop=pop_concat_df[pop_concat_df['Country Code']==single_country].loc[:, begin_year:end_year].T
# # combined=pd.concat([one_country_gdp, one_country_co2], axis=1)
# combined.columns=['GDP per capita (current us$)', 'CO2 per capita (metric tons)']
# np.log(combined).plot()
# plt.show()
# one_country_co2.describe()
