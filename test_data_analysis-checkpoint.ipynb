# %%
# Import Dependencies
# %matplotlib notebook
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read files into pandas DataFrames
pop_df = pd.read_csv("API_SP.POP.TOTL_DS2_en_csv_v2_713131.csv", header=2)
gdp_df = pd.read_csv("API_NY.GDP.MKTP.CD_DS2_en_csv_v2_713242.csv", header=2)
co2_df = pd.read_csv("API_EN.ATM.CO2E.PC_DS2_en_csv_v2_713061.csv", header=2)
gni_df = pd.read_csv("API_GNI_CLASS.csv", header=2)

# %%
# Set beginning and end time period
begin_year = "1995"
end_year = "2018"

# %%
single_countries=list(gni_df['Country Name'])
single_countries
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Côte d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Faeroe Islands',
#  'Fiji',
#  'Finland',
#  'France',
#  'French Polynesia',
#  'Gabon',
#  'Gambia, The',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong SAR, China',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran, Islamic Rep.',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Korea, Dem. Rep.',
#  'Korea, Rep.',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao SAR, China',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Micronesia, Fed. Sts.',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Macedonia',
#  'Northern Mariana Islands',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palau',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Samoa',
#  'San Marino',
#  'São Tomé and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Sint Maarten (Dutch part)',
#  'Slovak Republic',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Martin (French part)',
#  'St. Vincent and the Grenadines',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic',
#  'Taiwan, China',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Venezuela, RB',
#  'Vietnam',
#  'Virgin Islands (U.S.)',
#  'West Bank and Gaza',
#  'Yemen, Rep.',
#  'Zambia',
#  'Zimbabwe']

# %%
# Population DataFrame
pop_a_df = pop_df.loc[:,["Country Name", "Country Code"]]
pop_b_df = pop_df.loc[:, begin_year: end_year]
pop_concat_df = pd.concat([pop_a_df,pop_b_df], axis=1)
pop_concat_df = pop_concat_df.set_index("Country Name")

# GDP DataFrame
gdp_a_df = gdp_df.loc[:,["Country Name", "Country Code"]]
gdp_b_df = gdp_df.loc[:,begin_year: end_year]
gdp_concat_df = pd.concat([gdp_a_df,gdp_b_df], axis=1)
gdp_concat_df = gdp_concat_df.set_index("Country Name")

# CO2 DataFrame
co2_a_df = co2_df.loc[:,["Country Name", "Country Code"]]
co2_b_df = co2_df.loc[:,begin_year: end_year] * 1000 # Convert metric tons to kg.
co2_concat_df = pd.concat([co2_a_df,co2_b_df], axis=1)
co2_concat_df = co2_concat_df.set_index("Country Name")

# GNI DataFrame
gni_a_df = gni_df.loc[:,["Country Name", "Country Code"]]
gni_b_df = gni_df.loc[:,begin_year: end_year]
gni_concat_df = pd.concat([gni_a_df,gni_b_df], axis=1)
gni_concat_df = gni_concat_df.set_index("Country Name")

# %%
single_countries_pop=pop_concat_df.loc[single_countries]
single_countries_pop
# Out:
# C:\Users\jason\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                       Country Code        1995        1996        1997  \
# Country Name
# Afghanistan                    AFG  18110657.0  18853437.0  19357126.0
# Albania                        ALB   3187784.0   3168033.0   3148281.0
# Algeria                        DZA  28757785.0  29266405.0  29742979.0
# American Samoa                 ASM     53161.0     54211.0     55221.0
# Andorra                        AND     63850.0     64360.0     64327.0
# ...                            ...         ...         ...         ...
# Virgin Islands (U.S.)          VIR    107818.0    108095.0    108357.0
# West Bank and Gaza             PSE   2474666.0   2587997.0   2706518.0
# Yemen, Rep.                    YEM  14913315.0  15469274.0  15975668.0
# Zambia                         ZMB   9096607.0   9339733.0   9597609.0
# Zimbabwe                       ZWE  11410714.0  11541217.0  11653242.0
#
#                              1998        1999        2000        2001  \
# Country Name
# Afghanistan            19737765.0  20170844.0  20779953.0  21606988.0
# Albania                 3128530.0   3108778.0   3089027.0   3060173.0
# Algeria                30192754.0  30623406.0  31042235.0  31451514.0
# American Samoa            56171.0     57053.0     57821.0     58494.0
# Andorra                   64142.0     64370.0     65390.0     67341.0
# ...                           ...         ...         ...         ...
# Virgin Islands (U.S.)    108537.0    108599.0    108642.0    108549.0
# West Bank and Gaza      2776568.0   2848431.0   2922153.0   2997784.0
# Yemen, Rep.            16450310.0  16921149.0  17409072.0  17918373.0
# Zambia                  9866476.0  10140561.0  10415944.0  10692193.0
# Zimbabwe               11747072.0  11822719.0  11881477.0  11923914.0
#
#                              2002        2003  ...        2009        2010  \
# Country Name                                   ...
# Afghanistan            22600770.0  23680871.0  ...  28394813.0  29185507.0
# Albania                 3051010.0   3039616.0  ...   2927519.0   2913021.0
# Algeria                31855109.0  32264157.0  ...  35333881.0  35977455.0
# American Samoa            59080.0     59504.0  ...     56683.0     56079.0
# Andorra                   70049.0     73182.0  ...     84463.0     84449.0
# ...                           ...         ...  ...         ...         ...
# Virgin Islands (U.S.)    108510.0    108506.0  ...    108405.0    108358.0
# West Bank and Gaza      3075373.0   3154969.0  ...   3689099.0   3786161.0
# Yemen, Rep.            18443691.0  18985000.0  ...  22516460.0  23154855.0
# Zambia                 10971698.0  11256743.0  ...  13215139.0  13605984.0
# Zimbabwe               11954290.0  11982224.0  ...  12526968.0  12697723.0
#
#                              2011        2012        2013        2014  \
# Country Name
# Afghanistan            30117413.0  31161376.0  32269589.0  33370794.0
# Albania                 2905195.0   2900401.0   2895092.0   2889104.0
# Algeria                36661444.0  37383887.0  38140132.0  38923687.0
# American Samoa            55759.0     55667.0     55713.0     55791.0
# Andorra                   83747.0     82427.0     80774.0     79213.0
# ...                           ...         ...         ...         ...
# Virgin Islands (U.S.)    108292.0    108191.0    108044.0    107884.0
# West Bank and Gaza      3882986.0   3979998.0   4076708.0   4173398.0
# Yemen, Rep.            23807588.0  24473178.0  25147109.0  25823485.0
# Zambia                 14023193.0  14465121.0  14926504.0  15399753.0
# Zimbabwe               12894316.0  13115131.0  13350356.0  13586681.0
#
#                              2015        2016        2017        2018
# Country Name
# Afghanistan            34413603.0  35383128.0  36296400.0  37172386.0
# Albania                 2880703.0   2876101.0   2873457.0   2866376.0
# Algeria                39728025.0  40551404.0  41389198.0  42228429.0
# American Samoa            55812.0     55741.0     55620.0     55465.0
# Andorra                   78011.0     77297.0     77001.0     77006.0
# ...                           ...         ...         ...         ...
# Virgin Islands (U.S.)    107710.0    107510.0    107268.0    106977.0
# West Bank and Gaza      4270092.0   4367088.0   4454805.0   4569087.0
# Yemen, Rep.            26497889.0  27168210.0  27834821.0  28498687.0
# Zambia                 15879361.0  16363507.0  16853688.0  17351822.0
# Zimbabwe               13814629.0  14030390.0  14236745.0  14439018.0
#
# [218 rows x 25 columns]

# %%
years_list=[str(each_year) for each_year in range(int(begin_year), int(end_year))]
total_co2=co2_concat_df[years_list]*pop_concat_df[years_list]
total_co2.loc['World'].plot(title='Total CO2 Emission (Ten Billion Metric Tons)')

# %%
pop_concat_df[years_list].loc['World'].plot(title='Total Population (Billions)')

# %%
gdp_concat_df[years_list].loc['World'].plot(title='Total GDP (Ten Trillion Current US$)')

# %%
len(total_co2.sum(axis=0)/pop_concat_df.sum(axis=0))
# Out:
# 25

# %%
(total_co2.loc['World']/pop_concat_df.loc['World']).plot(title='World CO2 Per Capita (Metric Tons)')

# %%
total_co2.loc['World']
# Out:
# 1995    2.303752e+13
# 1996    2.357156e+13
# 1997    2.397501e+13
# 1998    2.411419e+13
# 1999    2.405919e+13
# 2000    2.468991e+13
# 2001    2.527663e+13
# 2002    2.564700e+13
# 2003    2.704779e+13
# 2004    2.839358e+13
# 2005    2.949001e+13
# 2006    3.056811e+13
# 2007    3.118050e+13
# 2008    3.218159e+13
# 2009    3.189190e+13
# 2010    3.347238e+13
# 2011    3.484750e+13
# 2012    3.547089e+13
# 2013    3.583759e+13
# 2014    3.613829e+13
# 2015             NaN
# 2016             NaN
# 2017             NaN
# Name: World, dtype: float64

# %%
print(total_co2.loc[single_countries, '2013'].sort_values(ascending=False))
# Out:
# Country Name
# China                       1.025801e+13
# United States               5.159161e+12
# India                       2.034752e+12
# Russian Federation          1.778561e+12
# Japan                       1.246516e+12
#                                 ...
# San Marino                           NaN
# São Tomé and Principe                NaN
# St. Martin (French part)             NaN
# Taiwan, China                        NaN
# Virgin Islands (U.S.)                NaN
# Name: 2013, Length: 218, dtype: float64

# %%
total_co2
# Out:
#                       1995          1996          1997          1998  \
# Country Name
# Aruba         1.668485e+09  1.690487e+09  1.745492e+09  1.796830e+09
# Afghanistan   1.243113e+09  1.177107e+09  1.096433e+09  1.041428e+09
# Angola        1.097533e+10  1.045828e+10  7.381671e+09  7.308331e+09
# Albania       2.086523e+09  2.016850e+09  1.543807e+09  1.752826e+09
# Andorra       4.253720e+08  4.547080e+08  4.657090e+08  4.913780e+08
# ...                    ...           ...           ...           ...
# Kosovo                 NaN           NaN           NaN           NaN
# Yemen, Rep.   1.046562e+10  1.063797e+10  1.335888e+10  1.220011e+10
# South Africa  3.622593e+11  3.644008e+11  3.861314e+11  3.777267e+11
# Zambia        2.170864e+09  1.870170e+09  2.390884e+09  2.313877e+09
# Zimbabwe      1.513004e+10  1.499436e+10  1.440764e+10  1.425363e+10
#
#                       1999          2000          2001          2002  \
# Country Name
# Aruba         1.807831e+09  2.379883e+09  2.409219e+09  2.438555e+09
# Afghanistan   8.214080e+08  7.737370e+08  8.177410e+08  1.070764e+09
# Angola        9.156499e+09  9.541534e+09  9.732218e+09  1.266582e+10
# Albania       2.984938e+09  3.021608e+09  3.223293e+09  3.751341e+09
# Andorra       5.133800e+08  5.243810e+08  5.243810e+08  5.317150e+08
# ...                    ...           ...           ...           ...
# Kosovo                 NaN           NaN           NaN           NaN
# Yemen, Rep.   1.389426e+10  1.464233e+10  1.620814e+10  1.576443e+10
# South Africa  3.752368e+11  3.786654e+11  3.720428e+11  3.566378e+11
# Zambia        1.807831e+09  1.822499e+09  1.906840e+09  1.983847e+09
# Zimbabwe      1.583411e+10  1.392360e+10  1.259614e+10  1.196542e+10
#
#                       2003          2004  ...          2008          2009  \
# Country Name                              ...
# Aruba         2.563233e+09  2.618238e+09  ...  2.658575e+09  2.629239e+09
# Afghanistan   1.195442e+09  9.497530e+08  ...  4.206049e+09  6.769282e+09
# Angola        9.064824e+09  1.879337e+10  ...  2.570934e+10  2.779219e+10
# Albania       4.294057e+09  4.165712e+09  ...  4.374731e+09  4.378398e+09
# Andorra       5.353820e+08  5.610510e+08  ...  5.390490e+08  5.170470e+08
# ...                    ...           ...  ...           ...           ...
# Kosovo                 NaN           NaN  ...           NaN           NaN
# Yemen, Rep.   1.730457e+10  1.888138e+10  ...  2.233936e+10  2.456157e+10
# South Africa  4.044591e+11  4.501866e+11  ...  4.967722e+11  5.031124e+11
# Zambia        2.112192e+09  2.145195e+09  ...  2.170864e+09  2.508228e+09
# Zimbabwe      1.065630e+10  9.486529e+09  ...  7.770373e+09  5.603176e+09
#
#                       2010          2011          2012          2013  \
# Country Name
# Aruba         2.508228e+09  2.500894e+09  1.349456e+09  8.617450e+08
# Afghanistan   8.463436e+09  1.224045e+10  1.075531e+10  1.001458e+10
# Angola        2.905731e+10  3.034076e+10  3.339904e+10  3.261796e+10
# Albania       4.598418e+09  5.240143e+09  4.910113e+09  5.064127e+09
# Andorra       5.170470e+08  4.913780e+08  4.877110e+08  4.767100e+08
# ...                    ...           ...           ...           ...
# Kosovo                 NaN           NaN           NaN           NaN
# Yemen, Rep.   2.343213e+10  1.966612e+10  1.866870e+10  2.549665e+10
# South Africa  4.740991e+11  4.705824e+11  4.687709e+11  4.663764e+11
# Zambia        2.691578e+09  2.937267e+09  3.667000e+09  3.956693e+09
# Zimbabwe      7.777707e+09  9.563536e+09  7.792375e+09  1.167573e+10
#
#                       2014  2015  2016  2017
# Country Name
# Aruba         8.727460e+08   NaN   NaN   NaN
# Afghanistan   9.809225e+09   NaN   NaN   NaN
# Angola        3.476316e+10   NaN   NaN   NaN
# Albania       5.716853e+09   NaN   NaN   NaN
# Andorra       4.620420e+08   NaN   NaN   NaN
# ...                    ...   ...   ...   ...
# Kosovo                 NaN   NaN   NaN   NaN
# Yemen, Rep.   2.269873e+10   NaN   NaN   NaN
# South Africa  4.897719e+11   NaN   NaN   NaN
# Zambia        4.503076e+09   NaN   NaN   NaN
# Zimbabwe      1.202043e+10   NaN   NaN   NaN
#
# [264 rows x 23 columns]

# %%
top_ten_co2_2013 = total_co2.loc[single_countries, '2013'].sort_values(ascending=False).head(10)
top_ten_co2_2014 = total_co2.loc[single_countries, '2014'].sort_values(ascending=False).head(10)
print(top_ten_co2_2013)
print(top_ten_co2_2014)
# Out:
# Country Name
# China                 1.025801e+13
# United States         5.159161e+12
# India                 2.034752e+12
# Russian Federation    1.778561e+12
# Japan                 1.246516e+12
# Germany               7.573125e+11
# Iran, Islamic Rep.    6.197780e+11
# Korea, Rep.           5.924992e+11
# Saudi Arabia          5.410475e+11
# Canada                5.171607e+11
# Name: 2013, dtype: float64
# Country Name
# China                 1.029193e+13
# United States         5.254279e+12
# India                 2.238377e+12
# Russian Federation    1.705346e+12
# Japan                 1.214048e+12
# Germany               7.198834e+11
# Iran, Islamic Rep.    6.494807e+11
# Saudi Arabia          6.010470e+11
# Korea, Rep.           5.871564e+11
# Canada                5.371935e+11
# Name: 2014, dtype: float64

# %%
top_ten_both = pd.concat([top_ten_co2_2013, top_ten_co2_2014], axis=1).plot.bar()
# Out:
# C:\Users\jason\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
(total_co2['2014']-total_co2['2013']).loc[single_countries].sort_values()
# Out:
# C:\Users\jason\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
# Country Name
# Russian Federation         -7.321532e+10
# Ukraine                    -4.457605e+10
# United Kingdom             -3.843016e+10
# Germany                    -3.742907e+10
# Japan                      -3.246762e+10
#                                 ...
# São Tomé and Principe                NaN
# St. Martin (French part)             NaN
# Taiwan, China                        NaN
# Virgin Islands (U.S.)                NaN
# West Bank and Gaza                   NaN
# Length: 218, dtype: float64

# %%
(total_co2.sum(axis=0)/pop_concat_df.sum(axis=0))
# Out:
# 1995            3249.16
# 1996            3287.21
# 1997            3247.94
# 1998            3186.38
# 1999            3182.04
# 2000            3223.17
# 2001            3224.29
# 2002            3261.09
# 2003            3419.02
# 2004            3558.88
# 2005            3661.01
# 2006            3769.78
# 2007            3842.03
# 2008            3935.77
# 2009            3877.26
# 2010            4038.56
# 2011            4190.29
# 2012            4233.58
# 2013            4198.61
# 2014                NaN
# Country Code        NaN
# dtype: object

# %%
#pop_concat_df.head()
#gdppc_concat_df.head()
#co2_concat_df.head()
gni_concat_df.head()
# Out:
#                Country Code 1995 1996 1997 1998 1999 2000 2001 2002 2003  ...  \
# Country Name                                                              ...
# Afghanistan             AFG    L    L    L    L    L    L    L    L    L  ...
# Albania                 ALB    L   LM    L   LM   LM   LM   LM   LM   LM  ...
# Algeria                 DZA   LM   LM   LM   LM   LM   LM   LM   LM   LM  ...
# American Samoa          ASM   UM   UM   UM   UM   UM   UM   UM   UM   UM  ...
# Andorra                 AND    H    H    H    H    H    H    H    H    H  ...
#
#                2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
# Country Name
# Afghanistan       L    L    L    L    L    L    L    L    L    L
# Albania          LM   LM   LM   LM   UM   UM   LM   UM   UM   UM
# Algeria          LM   LM   LM   UM   UM   UM   UM   UM   UM   UM
# American Samoa   UM   UM   UM   UM   UM   UM   UM   UM   UM   UM
# Andorra           H    H    H    H    H    H    H    H    H    H
#
# [5 rows x 21 columns]

# %%
# GDP per Capita DataFrame
gdppc_a_df = gdp_a_df
gdppc_b_df = gdp_concat_df.loc[:,"1995":"2014"].div(pop_concat_df.loc[:,"1995":"2014"])
gdppc_concat_df = pd.merge(gdppc_a_df, gdppc_b_df, on="Country Name")
gdppc_concat_df = gdppc_concat_df = gdppc_concat_df.set_index("Country Name")
gdppc_concat_df.head()
# Out:
#              Country Code          1995          1996          1997  \
# Country Name
# Aruba                 ABW  16439.356361  16586.068436  17927.749635
# Afghanistan           AFG           NaN           NaN           NaN
# Angola                AGO    397.179451    522.643807    514.295223
# Albania               ALB    750.604449   1009.977668    717.380567
# Andorra               AND  18461.064858  19017.174590  18353.059722
#
#                       1998          1999          2000          2001  \
# Country Name
# Aruba         19078.343191  19356.203389  20620.700626  20669.031969
# Afghanistan            NaN           NaN           NaN           NaN
# Angola          423.593660    387.784316    556.836318    527.333529
# Albania         813.790264   1033.241693   1126.683318   1281.659393
# Andorra       18894.521496  19261.710504  21936.530101  22228.846493
#
#                       2002          2003  ...          2005          2006  \
# Country Name                              ...
# Aruba         20436.887129  20833.761612  ...  23300.039558  24045.272483
# Afghanistan     179.426494    190.684009  ...    242.031379    263.733735
# Angola          872.494492    982.960899  ...   1902.422346   2599.566464
# Albania        1425.124849   1846.118813  ...   2673.787283   2972.743265
# Andorra       24741.493570  32776.442270  ...  41282.020122  43747.691849
#
#                       2007          2008          2009          2010  \
# Country Name
# Aruba         25835.132668  27084.703690  24630.453714  23512.602596
# Afghanistan     359.693480    364.660465    438.076034    543.303042
# Angola         3121.995637   4080.941410   3122.780766   3587.883798
# Albania        3595.037163   4370.540087   4114.140150   4094.362119
# Andorra       48582.220883  47785.089273  43338.866758  39736.354063
#
#                       2011          2012          2013          2014
# Country Name
# Aruba         24985.993281  24713.698045  25025.099563  25533.569780
# Afghanistan     591.162346    641.872034    637.165044    613.856333
# Angola         4615.468028   5100.095808   5254.882338   5408.410496
# Albania        4437.178067   4247.614279   4413.081743   4578.666720
# Andorra       41100.729938  38392.943901  40626.751632  42300.334128
#
# [5 rows x 21 columns]

# %%
# Ask user for country
country_input = input("Which country do you want to chart? ")
# Out:
# Which country do you want to chart? USA

# %%
# Graph GDP
gdppc_search = gdppc_concat_df.loc[(gdppc_concat_df["Country Code"]==country_input),"1995":"2014"].T
plt.plot(gdppc_search, marker='o', color='green')

# Graph CO2
co2_search = co2_concat_df.loc[(co2_concat_df["Country Code"]==country_input),"1995":"2014"].T
plt.plot(co2_search, marker='o', color='orange')

plt.xticks(rotation=90)
plt.xlabel("Year")
plt.ylabel("GDP per capita (current US$)")
plt.title(country_input)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'USA')

# %%
# Separate countries by income
begin_year='1995'
end_year='2014'
years_df_list=[]
years_list=[str(each_year) for each_year in range(int(begin_year), int(end_year)+1)]
idx_co2_concat_df=co2_concat_df.set_index('Country Code')
idx_gni_concat_df=gni_concat_df.set_index('Country Code')
for each_year in years_list: 
    each_year_df=pd.concat([idx_co2_concat_df[each_year], 
                            idx_gni_concat_df[each_year]], 
                           axis=1, 
                           sort=False, 
                           keys=['CO2', 'Class'])
    years_df_list.append(each_year_df.groupby('Class').mean())
co2_trend_by_class=pd.concat(years_df_list, axis=1, keys=years_list)
co2_trend_by_class.T.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
each_year_df.head()
# Out:
#              CO2 Class
# ABW  8410.064178     H
# AFG   293.946407     L
# AGO  1290.306776    UM
# ALB  1978.763312    UM
# AND  5832.906215     H
