# %%
# Code for the project

# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json

# %%
# Get the csv's and create all dataframes

# Population
population_df = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_713131.csv', header=2)
population_df.drop(columns=['Indicator Code', 'Unnamed: 64'])
population_df.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2011  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    102046.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  30117413.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  24220661.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2905195.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     83747.0
#
#          2012        2013        2014        2015        2016        2017  \
# ...

# %%
# Narrow down the years.
# pop1_df = population_df.loc[:,'Country Name']
# pop2_df = population_df.loc[:,'1960':'2018']
# pop_all_df = pd.concat([pop1_df, pop2_df], axis=1)
# pop_all_df.head()

# %%
# GDP
gdp_df = pd.read_csv('API_NY.GDP.MKTP.CD_DS2_en_csv_v2_713242.csv', header=2)
gdp_df.drop(columns=['Indicator Code', 'Unnamed: 64'])
gdp_df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
# ...

# %%
# Narrow down the years.
# gdp1_df = gdp_df.loc[:,'Country Name']
# gdp2_df = gdp_df.loc[:,'1960':'2018']
# gdp_all_df = pd.concat([gdp1_df, gdp2_df], axis=1)
# gdp_all_df.head()

# %%
# CO2 emissions
co2_df = pd.read_csv('API_EN.ATM.CO2E.PC_DS2_en_csv_v2_713061.csv', header=2)
co2_df.drop(columns=['Indicator Code'])
co2_df.head()
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1  Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2       Angola          AGO  CO2 emissions (metric tons per capita)
# 3      Albania          ALB  CO2 emissions (metric tons per capita)
# 4      Andorra          AND  CO2 emissions (metric tons per capita)
#
#    Indicator Code      1960      1961      1962      1963      1964      1965  \
# 0  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 1  EN.ATM.CO2E.PC  0.046057  0.053589  0.073721  0.074161  0.086174  0.101285
# 2  EN.ATM.CO2E.PC  0.100835  0.082204  0.210531  0.202737  0.213560  0.205891
# 3  EN.ATM.CO2E.PC  1.258195  1.374186  1.439956  1.181681  1.111742  1.166099
# 4  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
#
#    ...       2011       2012      2013      2014  2015  2016  2017  2018  \
# ...

# %%
# Narrow down the years.
# co2_1_df = co2_df.loc[:,'Country Name']
# co2_2_df = co2_df.loc[:,'1960':'2018']
# co2_all_df = pd.concat([co2_1_df, co2_2_df], axis=1)
# co2_all_df.head()

# %%
# Look at just one country
country_name = input("Country Name ")
gdp_one_df = gdp_df.loc[(gdp_df['Country Name'] == country_name)]
co2_one_df = co2_df.loc[(co2_df['Country Name'] == country_name)]
pop_one_df = population_df.loc[(population_df['Country Name'] == country_name)]

Combined_df = pd.concat([gdp_one_df, pop_one_df, co2_one_df], axis=0)
Combined_df.drop(columns=['Indicator Code'])
Combined_df
# Out:
# Country Name Angola
#   Country Name Country Code                          Indicator Name  \
# 2       Angola          AGO                       GDP (current US$)
# 2       Angola          AGO                       Population, total
# 2       Angola          AGO  CO2 emissions (metric tons per capita)
#
#    Indicator Code          1960          1961          1962          1963  \
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 2     SP.POP.TOTL  5.454933e+06  5.531472e+06  5.608539e+06  5.679458e+06
# 2  EN.ATM.CO2E.PC  1.008353e-01  8.220380e-02  2.105315e-01  2.027373e-01
#
#            1964          1965  ...          2011          2012          2013  \
# 2           NaN           NaN  ...  1.117897e+11  1.280529e+11  1.367099e+11
# 2  5.735044e+06  5.770570e+06  ...  2.422066e+07  2.510793e+07  2.601578e+07
# 2  2.135603e-01  2.058909e-01  ...  1.252681e+00  1.330219e+00  1.253776e+00
#
# ...

# %%
gdp_one_df.loc[:, '1960':'2018'].T.plot(kind='line')
co2_one_df.loc[:, '1960':'2018'].T.plot(kind='line')
pop_one_df.loc[:, '1960':'2018'].T.plot(kind='line')
